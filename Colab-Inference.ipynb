# %% [markdown]
# <a href="https://colab.research.google.com/github/RVC-Boss/GPT-SoVITS/blob/main/Colab-Inference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT-SoVITS Infer

# %% [markdown]
# ## Env Setup (Run Once Only)
# ## 环境配置, 只需运行一次

# %% [markdown]
# ### 1.

# %%
# %%writefile /content/setup.sh
# set -e
#
# cd /content
#
# git clone https://github.com/RVC-Boss/GPT-SoVITS.git
#
# cd GPT-SoVITS
#
# mkdir -p GPT_weights
#
# mkdir -p SoVITS_weights
#
# if conda env list | awk '{print $1}' | grep -Fxq "GPTSoVITS"; then
#     :
# else
#     conda create -n GPTSoVITS python=3.10 -y
# fi
#
# source activate GPTSoVITS
#
# pip install ipykernel
#
# bash install.sh --device CU126 --source HF

# %% [markdown]
# ### 2.

# %%
# %pip install -q condacolab
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh")
# !cd /content && bash setup.sh
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ✨🍰✨ Everything looks OK!
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# bash: /usr/local/lib/libtinfo.so.6: no version information available (required by bash)
# fatal: destination path 'GPT-SoVITS' already exists and is not an empty directory.

# %% [markdown]
# # Download Model

# %% [markdown]
# ### Download From HuggingFace

# %%
# Modify These
USER_ID = "AkitoP"
REPO_NAME = "GPT-SoVITS-v2-aegi"
BRANCH = "main"
GPT_PATH = "new_aegigoe-e100.ckpt"
SOVITS_PATH = "new_aegigoe_e60_s32220.pth"

# Do Not Modify
HF_BASE = "https://huggingface.co"
REPO_ID = f"{USER_ID}/{REPO_NAME}"
GPT_URL = f"{HF_BASE}/{REPO_ID}/blob/{BRANCH}/{GPT_PATH}"
SOVITS_URL = f"{HF_BASE}/{REPO_ID}/blob/{BRANCH}/{SOVITS_PATH}"

# !cd "/content/GPT-SoVITS/GPT_weights" && wget "{GPT_URL}"
# !cd "/content/GPT-SoVITS/SoVITS_weights" && wget "{SOVITS_URL}"
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# --2026-03-21 21:48:45--  https://huggingface.co/AkitoP/GPT-SoVITS-v2-aegi/blob/main/new_aegigoe-e100.ckpt
# Resolving huggingface.co (huggingface.co)... 3.165.160.11, 3.165.160.59, 3.165.160.61, ...
# Connecting to huggingface.co (huggingface.co)|3.165.160.11|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
#
# Username/Password Authentication Failed.
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# --2026-03-21 21:48:45--  https://huggingface.co/AkitoP/GPT-SoVITS-v2-aegi/blob/main/new_aegigoe_e60_s32220.pth
# Resolving huggingface.co (huggingface.co)... 3.165.160.11, 3.165.160.59, 3.165.160.61, ...
# Connecting to huggingface.co (huggingface.co)|3.165.160.11|:443... connected.
# HTTP request sent, awaiting response... 401 Unauthorized
#
# Username/Password Authentication Failed.

# %% [markdown]
# ### Download From ModelScope

# %%
# Modify These
USER_ID = "aihobbyist"
REPO_NAME = "GPT-SoVits-V2-models"
BRANCH = "master"
GPT_PATH = "Genshin_Impact/EN/GPT_GenshinImpact_EN_5.1.ckpt"
SOVITS_PATH = "Wuthering_Waves/CN/SV_WutheringWaves_CN_1.3.pth"

# Do Not Modify
HF_BASE = "https://www.modelscope.cn/models"
REPO_ID = f"{USER_ID}/{REPO_NAME}"
GPT_URL = f"{HF_BASE}/{REPO_ID}/resolve/{BRANCH}/{GPT_PATH}"
SOVITS_URL = f"{HF_BASE}/{REPO_ID}/resolve/{BRANCH}/{SOVITS_PATH}"

# !cd "/content/GPT-SoVITS/GPT_weights" && wget "{GPT_URL}"
# !cd "/content/GPT-SoVITS/SoVITS_weights" && wget "{SOVITS_URL}"
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# --2026-03-21 21:48:45--  https://www.modelscope.cn/models/aihobbyist/GPT-SoVits-V2-models/resolve/master/Genshin_Impact/EN/GPT_GenshinImpact_EN_5.1.ckpt
# Resolving www.modelscope.cn (www.modelscope.cn)... 47.251.62.57
# Connecting to www.modelscope.cn (www.modelscope.cn)|47.251.62.57|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs-cn-1.modelscope.cn/prod/lfs-objects/e6/cb/c66e3dc4c566cb3cdfbb5dc51189390503cba4125801f606f4be918e8e76?filename=GPT_GenshinImpact_EN_5.1.ckpt&namespace=aihobbyist&repository=GPT-SoVits-V2-models&revision=master&tag=model&auth_key=1774129726-23e3dcdb8fc74f888f3fd9f10d75d4b0-0-6d07c89c19b73300277bf0eff983c965 [following]
# --2026-03-21 21:48:46--  https://cdn-lfs-cn-1.modelscope.cn/prod/lfs-objects/e6/cb/c66e3dc4c566cb3cdfbb5dc51189390503cba4125801f606f4be918e8e76?filename=GPT_GenshinImpact_EN_5.1.ckpt&namespace=aihobbyist&repository=GPT-SoVits-V2-models&revision=master&tag=model&auth_key=1774129726-23e3dcdb8fc74f888f3fd9f10d75d4b0-0-6d07c89c19b73300277bf0eff983c965
# Resolving cdn-lfs-cn-1.modelscope.cn (cdn-lfs-cn-1.modelscope.cn)... 163.181.66.188, 163.181.66.189, 163.181.66.190, ...
# Connecting to cdn-lfs-cn-1.modelscope.cn (cdn-lfs-cn-1.modelscope.cn)|163.181.66.188|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 155312502 (148M) [application/octet-stream]
# Saving to: ‘GPT_GenshinImpact_EN_5.1.ckpt’
#
# GPT_GenshinImpact_E 100%[===================>] 148.12M  51.6MB/s    in 2.9s
#
# 2026-03-21 21:48:49 (51.6 MB/s) - ‘GPT_GenshinImpact_EN_5.1.ckpt’ saved [155312502/155312502]
#
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# --2026-03-21 21:48:49--  https://www.modelscope.cn/models/aihobbyist/GPT-SoVits-V2-models/resolve/master/Wuthering_Waves/CN/SV_WutheringWaves_CN_1.3.pth
# Resolving www.modelscope.cn (www.modelscope.cn)... 47.251.62.57
# Connecting to www.modelscope.cn (www.modelscope.cn)|47.251.62.57|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://cdn-lfs-cn-1.modelscope.cn/prod/lfs-objects/92/b0/8bd683688d193fd867be7c3dc28f7e3bbf36088547dcf6060fe3ab0d7a1e?filename=SV_WutheringWaves_CN_1.3.pth&namespace=aihobbyist&repository=GPT-SoVits-V2-models&revision=master&tag=model&auth_key=1774129729-0c3c92614f544d6aa2983ff887d8395d-0-b138b518b1c4d129f285f918d774164c [following]
# --2026-03-21 21:48:49--  https://cdn-lfs-cn-1.modelscope.cn/prod/lfs-objects/92/b0/8bd683688d193fd867be7c3dc28f7e3bbf36088547dcf6060fe3ab0d7a1e?filename=SV_WutheringWaves_CN_1.3.pth&namespace=aihobbyist&repository=GPT-SoVits-V2-models&revision=master&tag=model&auth_key=1774129729-0c3c92614f544d6aa2983ff887d8395d-0-b138b518b1c4d129f285f918d774164c
# Resolving cdn-lfs-cn-1.modelscope.cn (cdn-lfs-cn-1.modelscope.cn)... 163.181.66.188, 163.181.66.189, 163.181.66.190, ...
# Connecting to cdn-lfs-cn-1.modelscope.cn (cdn-lfs-cn-1.modelscope.cn)|163.181.66.188|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85006074 (81M) [application/octet-stream]
# Saving to: ‘SV_WutheringWaves_CN_1.3.pth’
#
# SV_WutheringWaves_C 100%[===================>]  81.07M  51.4MB/s    in 1.6s
#
# 2026-03-21 21:48:51 (51.4 MB/s) - ‘SV_WutheringWaves_CN_1.3.pth’ saved [85006074/85006074]

# %% [markdown]
# # Launch WebUI
# # 启动 WebUI

# %%
# !cd /content/GPT-SoVITS && source activate GPTSoVITS && export is_share=True && python webui.py
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Running on local URL:  http://0.0.0.0:9874
# Running on public URL: https://f82f13b8690d7395a8.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# "/usr/local/envs/GPTSoVITS/bin/python" -s tools/uvr5/webui.py "cuda:0" True 9873 True
# /usr/local/envs/GPTSoVITS/lib/python3.10/site-packages/requests/__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.2.0)/charset_normalizer (3.4.6) doesn't match a supported version!
#   warnings.warn(
# Running on local URL:  http://0.0.0.0:9873
# Running on public URL: https://216ff8b8bd8d9ffe32.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
